# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit, cross_val_score, GridSearchCV
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import r2_score
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
rb_df = pd.read_csv('data/Copy of Pahowdy\'s MS Database - RB1.csv')

# %%
new_header = rb_df.iloc[0] 
rb_df = rb_df[1:] 
rb_df.columns = new_header

# %%
rb_df.drop(['my Player ID', 'School', 'Conference', 'NFL POS', 'Years Played', 'Years >= 20 Recs', 
            'Production Score (Pos Specific)', 'Combine Score', 'Post Draft', 'PRE-DRAFT', '# of top 5  finishes', 
            '# of top  12 finishes', '# of top  24 finishes', '# of top  36 finishes', 
            '# of 1000 Rush yards seasons'],axis=1, inplace=True)

# %%
# drop 2020 college players
rb_df.drop(list(range(1, 17)), inplace=True)

# %%
rb_df = rb_df.reset_index(drop=True)

# %%
rb_df = rb_df.set_index('Name')

# %%
# function to change elements to numeric
def clean(df):
    for i in df:
        if isinstance(i, str):
            var = pd.to_numeric(df[f'{i}'], errors='coerce')
            df[f'{i}'] = var
        else:
            var = pd.to_numeric(df[i], errors='coerce')
            df[i] = var
    return df

# %%
# elements to numeric
rb_df = clean(rb_df)

# %%
rb_df.hist(figsize=(20,15))
plt.show()

# %%
rookies_2020 = rb_df.iloc[0:54]

# %%
rb_df = rb_df.iloc[54:]
train_set, test_set = train_test_split(rb_df, test_size=0.2, random_state=42)

# %%
rb_df = train_set.copy()

# %%
corr_matrix = rb_df.corr()
corr_matrix['AVG PPG (PPR) Season 1-3'].sort_values(ascending=False)
# Out:
# 0
# AVG PPG (PPR) Season 1-3         1.000000
# ppr pts Best                     0.491406
# ppr ppg Best                     0.478303
# ppr ppg AVG                      0.476850
# ppr pts AVG                      0.476552
# yards per team att  Best         0.471962
# yards per team att  AVG          0.468464
# All Yards                        0.449229
# ppr ppg Last                     0.424690
# Last                             0.421116
# yards per team att  Last         0.405819
# total dominator AVG              0.404281
# total dominator Best             0.400899
# Touches                          0.380426
# TDOa AVG                         0.371908
# 22.0                             0.368199
# 19.0                             0.361900
# 18.0                             0.357680
# Rush College Dominator Rating    0.355269
# yards per team att  First        0.334161
# total dominator Last             0.332419
# 21.0                             0.331094
# TDOa First                       0.320695
# WaSS                             0.317955
# TDOa Best                        0.316971
# 20.0                             0.308837
# ppr pts First                    0.305985
# total dominator First            0.296951
# ppr ppg First                    0.279097
# HaSS                             0.269299
# RUSH AVG                         0.215618
# rec                              0.214809
# G                                0.208667
# TDOa Last                        0.206146
# REC/g                            0.158587
# Broad                            0.134388
# Arm Length                       0.096981
# Draft Year                       0.080330
# YPTch                            0.059508
# Verticle                         0.057550
# SPORK (discount SPAQ-x)          0.056651
# Hand Size                        0.034970
# height                           0.034104
# weight                          -0.076581
# BMI                             -0.122894
# Bench                           -0.125410
# Shuttle                         -0.125838
# 3 Cone                          -0.165570
# rec yards  Last                 -0.173549
# rec yards  First                -0.191452
# 23.0                            -0.201865
# rec yards  AVG                  -0.215618
# rec yards  Best                 -0.226780
# 40 time                         -0.325010
# Age IN DRAFT YEAR (9/1/dy)      -0.326117
# DP                              -0.581462
# DR                              -0.587002
# Name: AVG PPG (PPR) Season 1-3, dtype: float64

# %%
attributes = ['AVG PPG (PPR) Season 1-3', 'yards per team att  Best', 'ppr ppg Best', 'All Yards', 'total dominator Best']

# %%
pd.plotting.scatter_matrix(rb_df[attributes], figsize=(12, 8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb67e92a9d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb67fb3ac10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb67fb72d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb67fb8a310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb681083890>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb681096e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb681e41450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb681e76910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb681e76950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb681eacfd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb681f22a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb681f59f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb681f98550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb682bebad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb682c16b90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb682c64610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb682c98b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb682cd9150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb682d106d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb682d45c50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb682d86210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb682dbc790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb682df2d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb682e342d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb682e68850>]],
#       dtype=object)

# %%
rb_labels = rb_df['AVG PPG (PPR) Season 1-3'].fillna(0)
rookies_2020_labels = rookies_2020['AVG PPG (PPR) Season 1-3'].fillna(0)

# %%
rb_df.drop(['AVG PPG (PPR) Season 1-3'], axis=1, inplace=True)

# %%
undrafted_dr = rb_df['DR'].max()+1
undrafted_dp = rb_df['DP'].max()+1

# %%
# changed nan in draft round and draft position to 8 & 255
def draft_nan(df):
    df['DR'].fillna(undrafted_dr, inplace=True)
    df['DP'].fillna(undrafted_dp, inplace=True)
    return df

# %%
# fill nan in breakout age to 0
def age_nan(df):
    df[18.0].fillna(0, inplace=True)
    df[19.0].fillna(0, inplace=True)
    df[20.0].fillna(0, inplace=True)
    df[21.0].fillna(0, inplace=True)
    df[22.0].fillna(0, inplace=True)
    df[23.0].fillna(0, inplace=True)
    return df

# %%
rb_df = draft_nan(rb_df)
rb_df = age_nan(rb_df)
rookies_2020 = draft_nan(rookies_2020)
rookies_2020 = age_nan(rookies_2020)

# %%
num_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy="mean")),
    ('std_scaler', StandardScaler())])
rb_df_prepared = num_pipeline.fit_transform(rb_df)

# %%
lin_reg = LinearRegression()
lin_reg.fit(rb_df_prepared, rb_labels)
# Out:
# LinearRegression()

# %%
rb_predictions = lin_reg.predict(rb_df_prepared)
lin_mse = mse(rb_labels, rb_predictions)  
lin_rmse = np.sqrt(lin_mse)
lin_rmse
# Out:
# 3.365126090492233

# %%
df = pd.DataFrame({'Actual': rb_labels, 'Predicted': rb_predictions})
df = df.sort_values(by='Predicted', ascending=False)

# %%
plt.scatter(rb_labels, rb_predictions)

# %%
r2_score(rb_labels, rb_predictions)
# Out:
# 0.47705546355007056

# %%
tree_reg = DecisionTreeRegressor()
tree_reg.fit(rb_df_prepared, rb_labels)
# Out:
# DecisionTreeRegressor()

# %%
rb_predictions = tree_reg.predict(rb_df_prepared)
tree_mse = mse(rb_labels, rb_predictions)
tree_rmse = np.sqrt(tree_mse)
tree_rmse
# Out:
# 0.0

# %%
scores = cross_val_score(tree_reg, rb_df_prepared, rb_labels, 
                         scoring="neg_mean_squared_error", cv=10) 
tree_rmse_scores = np.sqrt(-scores)

# %%
def display_scores(scores):
    print('Scores:', scores)
    print('Mean:', scores.mean())
    print('SD:', scores.std())

# %%
display_scores(tree_rmse_scores)
# Out:
# Scores: [4.5440524  4.92487693 4.90933664 5.65496394 4.86459278 6.02579701
#  6.17204065 4.90343014 4.95571971 5.14869402]
# Mean: 5.210350422899849
# SD: 0.5182592606343444

# %%
lin_scores = cross_val_score(lin_reg, rb_df_prepared, rb_labels, scoring="neg_mean_squared_error", cv=10)
lin_rmse_scores = np.sqrt(-lin_scores)
display_scores(lin_rmse_scores)
# Out:
# Scores: [3.72946323 3.70931407 3.50039813 4.53067299 3.85635057 4.55831111
#  4.7954259  4.13442449 3.69809162 4.07333342]
# Mean: 4.058578552314023
# SD: 0.41644147932841624

# %%
df = pd.DataFrame({'Actual': rb_labels, 'Predicted': rb_predictions})
df = df.sort_values(by='Predicted', ascending=False)

# %%
plt.scatter(rb_labels, rb_predictions)

# %%
r2_score(rb_labels, rb_predictions)
# Out:
# 1.0

# %%
forest_reg = RandomForestRegressor()
forest_reg.fit(rb_df_prepared, rb_labels)
# Out:
# RandomForestRegressor()

# %%
rb_predictions = forest_reg.predict(rb_df_prepared)
forest_mse = mse(rb_labels, rb_predictions)
forest_rmse = np.sqrt(forest_mse)
forest_rmse
# Out:
# 1.3336119094248382

# %%
forest_scores = cross_val_score(forest_reg, rb_df_prepared, rb_labels, scoring="neg_mean_squared_error", cv=10)
forest_rmse_scores = np.sqrt(-forest_scores)
display_scores(forest_rmse_scores)
# Out:
# Scores: [3.23687348 3.11454057 3.11882534 3.42652443 3.65992367 4.7166796
#  4.25608875 3.60373317 3.39411577 3.67960106]
# Mean: 3.620690583060152
# SD: 0.48524517085468666

# %%
df = pd.DataFrame({'Actual': rb_labels, 'Predicted': rb_predictions})
df = df.sort_values(by='Predicted', ascending=False)

# %%
plt.scatter(rb_labels, rb_predictions)

# %%
r2_score(rb_labels, rb_predictions)
# Out:
# 0.9159001985579934

# %%
rookies_2020.drop(['AVG PPG (PPR) Season 1-3'], axis=1, inplace=True)

# %%
spork_mean = rb_df['SPORK (discount SPAQ-x)'].mean()

# %%
rookies_2020['SPORK (discount SPAQ-x)'].fillna(spork_mean, inplace=True)

# %%
num_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy="mean")),
    ('std_scaler', StandardScaler())])
rb_df_prepared = num_pipeline.fit_transform(rookies_2020)

# %%
rb_predictions = forest_reg.predict(rb_df_prepared)

# %%
df = pd.DataFrame({'Actual': rookies_2020_labels, 'Predicted': rb_predictions})
df = df.sort_values(by='Predicted', ascending=False)

# %%
param_grid = [
{'n_estimators': [3, 10, 30], 'max_features': [2, 4, 6, 8]},
{'bootstrap': [False], 'n_estimators': [3, 10], 'max_features': [2, 3, 4]},
]

# %%
forest_reg = RandomForestRegressor()

# %%
grid_search = GridSearchCV(forest_reg, param_grid, cv=5, scoring='neg_mean_squared_error',
return_train_score=True)

# %%
grid_search.fit(rb_df_prepared, rb_labels)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid=[{'max_features': [2, 4, 6, 8],
#                           'n_estimators': [3, 10, 30]},
#                          {'bootstrap': [False], 'max_features': [2, 3, 4],
#                           'n_estimators': [3, 10]}],
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
grid_search.best_params_
# Out:
# {'max_features': 8, 'n_estimators': 30}

# %%
grid_search.best_estimator_
# Out:
# RandomForestRegressor(max_features=8, n_estimators=30)

# %%
cvres = grid_search.cv_results_

# %%
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(np.sqrt(-mean_score), params)
# Out:
# 4.544872978441234 {'max_features': 2, 'n_estimators': 3}
# 3.998722930370242 {'max_features': 2, 'n_estimators': 10}
# 3.9716245479212215 {'max_features': 2, 'n_estimators': 30}
# 4.500706823176991 {'max_features': 4, 'n_estimators': 3}
# 3.991087724954622 {'max_features': 4, 'n_estimators': 10}
# 3.795616048021756 {'max_features': 4, 'n_estimators': 30}
# 4.396754786617164 {'max_features': 6, 'n_estimators': 3}
# 3.8695876718973694 {'max_features': 6, 'n_estimators': 10}
# 3.879123754778474 {'max_features': 6, 'n_estimators': 30}
# 4.277356256698001 {'max_features': 8, 'n_estimators': 3}
# 3.8961042415648377 {'max_features': 8, 'n_estimators': 10}
# 3.7403798373247925 {'max_features': 8, 'n_estimators': 30}
# 4.574769186618272 {'bootstrap': False, 'max_features': 2, 'n_estimators': 3}
# 4.019527674958985 {'bootstrap': False, 'max_features': 2, 'n_estimators': 10}
# 4.538185647869541 {'bootstrap': False, 'max_features': 3, 'n_estimators': 3}
# 4.017168876390046 {'bootstrap': False, 'max_features': 3, 'n_estimators': 10}
# 4.575514816400974 {'bootstrap': False, 'max_features': 4, 'n_estimators': 3}
# 4.029182819013362 {'bootstrap': False, 'max_features': 4, 'n_estimators': 10}

# %%
feature_importances = grid_search.best_estimator_.feature_importances_
feature_importances
# Out:
# array([0.07986993, 0.14814011, 0.01299772, 0.00569175, 0.01242101,
#        0.02085978, 0.03357422, 0.01725381, 0.0107048 , 0.01034754,
#        0.00688913, 0.01983807, 0.01148599, 0.01173075, 0.01109026,
#        0.00856808, 0.01513064, 0.00869969, 0.01344569, 0.01351832,
#        0.01085778, 0.01611621, 0.01839903, 0.00935685, 0.02336061,
#        0.00778383, 0.0108058 , 0.00848455, 0.01125142, 0.02078219,
#        0.02506533, 0.03749376, 0.01063831, 0.03274277, 0.03171048,
#        0.03426299, 0.01427712, 0.00986451, 0.0106444 , 0.01061786,
#        0.00389233, 0.00130678, 0.01013241, 0.01293258, 0.01446919,
#        0.01593717, 0.00679077, 0.00926021, 0.0132637 , 0.00946373,
#        0.01127814, 0.00726028, 0.01493243, 0.01308813, 0.01171609,
#        0.01750293])

# %%
sorted(zip(feature_importances, attributes), reverse=True)
# Out:
# [(0.14814010925945348, 'yards per team att  Best'),
#  (0.07986993121055444, 'AVG PPG (PPR) Season 1-3'),
#  (0.012997722845249195, 'ppr ppg Best'),
#  (0.012421014950340344, 'total dominator Best'),
#  (0.005691754330079879, 'All Yards')]
